# %%
import scipy.io
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt 
from sklearn.preprocessing import StandardScaler

# %%
mat = scipy.io.loadmat(r'C:\Users\MOBS\Desktop\Datasettone.mat')
data = pd.DataFrame(np.hstack((mat['X'], mat['Y'])))
Y=data[5000]
data.pop(5000);
X_train, X_test, y_train, y_test = train_test_split(data, Y, test_size=0.3)

# %%
rf=RandomForestClassifier(n_estimators=1250)
scaler=StandardScaler()

# %%
pipe=Pipeline([('Scaler',scaler),('Rf',rf)])

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('Scaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('Rf', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#       ...n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False))])

# %%
preds=rf.predict(X_test)
roc_auc_score(y_test,preds)
# Out:
# 0.5005420559164556

# %%
fpr, tpr, thresholds=roc_curve(y_test,preds)

# %%
plt.plot(fpr,tpr)

# %%
plt.plot(X_train(1,:))
# Out:
#   File "<ipython-input-103-acdc925b443d>", line 1
#     plt.plot(X_train(1,:))
#                        ^
# SyntaxError: invalid syntax

# %%
plt.plot(np.std(data.values[Y==1],axis=1))
plt.plot(np.std(data.values[Y==0],axis=1))
plt.legend([1,0])

# %%
np.mean(np.std(data.values[Y==1],axis=0))
# Out:
# 758.1380376976518

# %%
np.mean(np.std(data.values[Y==0],axis=0))
# Out:
# 743.3147502876378

# %%
plt.plot(data.values[3000])

# %%
plt.plot(np.mean(np.std(np.std(data.values,axis=1),axis=0)))

# %%
plt.plot(np.mean(data.values[np.std(data.values,axis=1)>100],axis=1))
plt.plot(np.mean(data.values[np.std(data.values,axis=1)<100]*10,axis=1))
plt.legend([1,0])

# %%
data.values-np.std(data.values,axis=1).T
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-153-cd1cfbedcd36> in <module>()
# ----> 1 data.values-np.std(data.values,axis=1).T
#
# ValueError: operands could not be broadcast together with shapes (3468,5000) (3468,)
